# %% [markdown]
# <a href="https://colab.research.google.com/github/gokila-a/Resume_Screening_Using_RAG_ChromaDB_LLM/blob/main/Resume_Screening_CLEAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nbformat

with open("Resume_Screening_Using_RAG_ChromaDB_LLM.ipynb", "r", encoding="utf-8") as f:
    nb = nbformat.read(f, as_version=4)

# Remove widgets
nb.metadata.pop("widgets", None)

# Clear all outputs
for cell in nb.cells:
    if cell.cell_type == "code":
        cell.outputs = []
        cell.execution_count = None

with open("Resume_Screening_CLEAN.ipynb", "w", encoding="utf-8") as f:
    nbformat.write(nb, f)

print("Created Resume_Screening_CLEAN.ipynb")
# Out:
# Created Resume_Screening_CLEAN.ipynb
